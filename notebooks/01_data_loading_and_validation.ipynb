# %% [markdown]
# <a href="https://colab.research.google.com/github/neelgenius/xai_credit_risk/blob/main/notebooks/01_data_loading_and_validation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Colab notebook ready")
# Out:
# Colab notebook ready

# %%
# !git clone https://github.com/neelgenius/xai_credit_risk.git
# Out:
# Cloning into 'xai_credit_risk'...
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 18 (delta 5), reused 7 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (18/18), 9.60 KiB | 2.40 MiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %%
cd xai_credit_risk/notebooks/
# Out:
# /content/xai_credit_risk/notebooks

# %%
ls
# Out:
# 01_data_loading_and_validation.ipynb
